# %%
import pandas as pd
import plotly.express as px

# Load the synthetic dataset CSV
df = pd.read_csv('synthetic_sales_data.csv')

print(df.head())
# TreeMap
fig_treemap = px.treemap(
    df,
    path=['Root', 'Region', 'Category', 'Subcategory'],
    values='Sales',
    color='Sales',
    color_continuous_scale='RdBu',
    title='Sales TreeMap by Region, Category, and Subcategory'
)
fig_treemap.show()

# Sunburst
fig_sunburst = px.sunburst(
    df,
    path=['Root', 'Region', 'Category', 'Subcategory'],
    values='Sales',
    color='Sales',
    color_continuous_scale='RdBu',
    title='Sales Sunburst by Region, Category, and Subcategory'
)
fig_sunburst.show()
# Out:
#         Root Region     Category  Subcategory  Sales
# 0  SalesData  North         Food    Groceries   7200
# 1  SalesData  North         Food       Snacks   4300
# 2  SalesData  North         Food    Beverages   3100
# 3  SalesData  North  Electronics  Accessories   6400
# 4  SalesData  North  Electronics       Phones   5200
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
